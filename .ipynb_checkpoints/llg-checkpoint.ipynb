# %%
import matplotlib.pyplot as plt
import japanize_matplotlib
import matplotlib.ticker as ticker
import numpy as np

params_data = np.loadtxt("llg_params.dat")

Lx = params_data[0]
N_steps = params_data[1]
lam = params_data[2]
h_app_norm = params_data[3]
dt = params_data[4]
gamma = params_data[5]

title_text = rf'$Lx = 128, hx=1, hz = 10, dt = 0.010, J = 1, \lambda = 0.05, k = 0.00, \omega = 20$'

llg_data = np.loadtxt("llg.dat")
step = llg_data[:, 0]
m_n0_step_x = llg_data[:, 1]

fig, ax = plt.subplots(figsize=(8, 6))
ax.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 10
#       8 Lx = params_data[0]
#       9 N_steps = params_data[1]
# ---> 10 lam = parparparams_data[2]
#      11 h_app_norm = params_data[3]
#      12 dt = params_data[4]
#
# NameError: name 'parparparams_data' is not defined
